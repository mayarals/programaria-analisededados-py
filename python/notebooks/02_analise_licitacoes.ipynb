# %%
import pandas as pd

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
df = pd.read_csv(
    '/content/drive/MyDrive/dados-programaria/licitacoes.csv',
    encoding='latin1',
    sep=';'
)

# %%
df.head(10)
# Out:
#    Número Licitação  Código UG                                       Nome UG  \
# 0             12016     160438     COMANDO 2 BRIGADA DE CAVALARIA MECANIZADA
# 1             12017     160203       2º BATALHAO DE ENGENHARIA DE CONSTRUCAO
# 2             12017     193002  DEPARTAMENTO NACIONAL DE OBRAS CONT.AS SECAS
# 3             12018     925135              BANCO CENTRAL DO BRASIL - RECIFE
# 4             12018     110101     GABINETE DA VICE-PRESIDENCIA DA REPUBLICA
# 5             12018     110102  SUPERINTENDENCIA REG. DE ADMIN. DA 2ª REGIAO
# 6             12018     110746            INTERVENCAO FEDERAL RIO DE JANEIRO
# 7             12018     113207  COMISSAO NACIONAL DE ENERGIA NUCLEAR-CRCN-CO
# 8             12018     120006               GRUPAMENTO DE APOIO DE BRASILIA
# 9             12018     120628                  GRUPAMENTO DE APOIO DE BELEM
#
#    Código Modalidade Compra             Modalidade Compra    Número Processo  \
# ...

# %%
df.columns
# Out:
# Index(['Número Licitação', 'Código UG', 'Nome UG', 'Código Modalidade Compra',
#        'Modalidade Compra', 'Número Processo', 'Objeto', 'Situação Licitação',
#        'Código Órgão Superior', 'Nome Órgão Superior', 'Código Órgão',
#        'Nome Órgão', 'UF', 'Município', 'Data Resultado Compra',
#        'Data Abertura', 'Valor Licitação'],
#       dtype='object')

# %%
df[df['Situação Licitação']=='Encerrado']
# Out:
#        Número Licitação  Código UG  \
# 3                 12018     925135
# 16                12018     130129
# 18                12018     135097
# 19                12018     152140
# 24                12018     153092
# ...                 ...        ...
# 15327         907662018     926130
# 15328         907732018     926130
# 15329         908252018     926130
# 15333         990922018     158139
# 15334         996252018     153035
#
#                                             Nome UG  Código Modalidade Compra  \
# 3                  BANCO CENTRAL DO BRASIL - RECIFE                         6
# 16       SUPERINT.REG.DE DESENV.DA LAV.CACAUEIRA/MT                         6
# 18                                     EMBRAPA CAFE                         7
# 19                    IFB - CAMPUS TAGUATINGA NORTE                         6
# 24                       BIBLIOTECA CENTRAL DA UFPE                         6
# ...

# %%
df['Situação Licitação'].value_counts()
# Out:
# Situação Licitação
# Encerrado                         9016
# Publicado                         3709
# Evento de Resultado de Julgame    1922
# Retificação                        127
# Evento de Alteração Publicad        93
# Evento de Suspensão Publicado       72
# Anulação                            67
# Revogação                           63
# Divulgado                           55
# Evento de Adiamento Publicado       46
# Evento de Retificação Public        45
# Evento de Revogação Publicad        40
# Evento de Alteração de Resul        37
# Evento de Anulação Publicado        18
# Evento de Retificação Divulg         7
# Inválido                             4
# Evento de Habilitação Public         4
# Evento de Alteração Divulgad         4
# Evento de Reabertura de Prazo        4
# Evento de Adiamento Divulgado        3
# Name: count, dtype: int64

# %% [markdown]
# # Tratando valores faltantes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15336 entries, 0 to 15335
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Número Licitação          15336 non-null  int64
#  1   Código UG                 15336 non-null  int64
#  2   Nome UG                   15336 non-null  object
#  3   Código Modalidade Compra  15336 non-null  int64
#  4   Modalidade Compra         15336 non-null  object
#  5   Número Processo           15336 non-null  object
#  6   Objeto                    15336 non-null  object
#  7   Situação Licitação        15336 non-null  object
#  8   Código Órgão Superior     15336 non-null  int64
#  9   Nome Órgão Superior       15336 non-null  object
#  10  Código Órgão              15336 non-null  int64
#  11  Nome Órgão                15336 non-null  object
#  12  UF                        15336 non-null  object
# ...

# %%
len(df)
# Out:
# 15336

# %%
df.groupby('Data Abertura', dropna=False)['Número Licitação'].nunique()
# Out:
# Data Abertura
# 01/06/2018       1
# 01/10/2018       5
# 01/11/2018      27
# 01/12/2018       1
# 02/04/2018       1
#               ...
# 31/07/2018       1
# 31/08/2018       1
# 31/10/2018      27
# 31/12/2018       9
# NaN           1512
# Name: Número Licitação, Length: 180, dtype: int64

# %%
df.groupby('Data Abertura', dropna=False)['Número Licitação'].nunique()
# Out:
# Data Abertura
# 01/06/2018       1
# 01/10/2018       5
# 01/11/2018      27
# 01/12/2018       1
# 02/04/2018       1
#               ...
# 31/07/2018       1
# 31/08/2018       1
# 31/10/2018      27
# 31/12/2018       9
# NaN           1512
# Name: Número Licitação, Length: 180, dtype: int64

# %%
df['Data Abertura'].mode()
# Out:
# 0    04/12/2018
# Name: Data Abertura, dtype: object

# %%
df.loc[df['Data Abertura'].isnull(), 'Data Abertura'] = '00/00/0000'

# %%
df['Data Abertura'].isnull().value_counts()
# Out:
# Data Abertura
# False    15336
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15336 entries, 0 to 15335
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Número Licitação          15336 non-null  int64
#  1   Código UG                 15336 non-null  int64
#  2   Nome UG                   15336 non-null  object
#  3   Código Modalidade Compra  15336 non-null  int64
#  4   Modalidade Compra         15336 non-null  object
#  5   Número Processo           15336 non-null  object
#  6   Objeto                    15336 non-null  object
#  7   Situação Licitação        15336 non-null  object
#  8   Código Órgão Superior     15336 non-null  int64
#  9   Nome Órgão Superior       15336 non-null  object
#  10  Código Órgão              15336 non-null  int64
#  11  Nome Órgão                15336 non-null  object
#  12  UF                        15336 non-null  object
# ...

# %%
df.groupby('Data Abertura', dropna=False)['Número Licitação'].nunique()
# Out:
# Data Abertura
# 00/00/0000    1512
# 01/06/2018       1
# 01/10/2018       5
# 01/11/2018      27
# 01/12/2018       1
#               ...
# 31/01/2018       1
# 31/07/2018       1
# 31/08/2018       1
# 31/10/2018      27
# 31/12/2018       9
# Name: Número Licitação, Length: 180, dtype: int64
